# %% [markdown]
# # Convert ipynb file to py file
#
# We can run the following code in notebook, or we can run this in the *terminal*:
#
# jupyter nbconvert --to python main_Train_MFLSTM_hourly_de.ipynb --output test.py

# %%
# install the nbconvert package if it is not already done

# !pip install nbconvert
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting nbconvert
#   Downloading nbconvert-7.16.6-py3-none-any.whl (258 kB)
#      |████████████████████████████████| 258 kB 10.0 MB/s eta 0:00:01
# Collecting defusedxml
#   Downloading defusedxml-0.7.1-py2.py3-none-any.whl (25 kB)
# Requirement already satisfied: packaging in /usr/lib/python3.9/site-packages (from nbconvert) (20.9)
# Collecting importlib-metadata>=3.6
#   Downloading importlib_metadata-8.7.0-py3-none-any.whl (27 kB)
# Collecting jupyterlab-pygments
#   Downloading jupyterlab_pygments-0.3.0-py3-none-any.whl (15 kB)
# Collecting bleach[css]!=5.0.0
#   Downloading bleach-6.2.0-py3-none-any.whl (163 kB)
#      |████████████████████████████████| 163 kB 21.4 MB/s eta 0:00:01
# Collecting nbformat>=5.7
#   Downloading nbformat-5.10.4-py3-none-any.whl (78 kB)
#      |████████████████████████████████| 78 kB 6.5 MB/s  eta 0:00:011
# Collecting pandocfilters>=1.4.1
#   Downloading pandocfilters-1.5.1-py2.py3-none-any.whl (8.7 kB)
# Collecting traitlets>=5.1
#   Using cached traitlets-5.14.3-py3-none-any.whl (85 kB)
# Collecting beautifulsoup4
#   Downloading beautifulsoup4-4.14.3-py3-none-any.whl (107 kB)
#      |████████████████████████████████| 107 kB 23.8 MB/s eta 0:00:01
# Collecting jupyter-core>=4.7
#   Downloading jupyter_core-5.8.1-py3-none-any.whl (28 kB)
# Collecting markupsafe>=2.0
#   Downloading markupsafe-3.0.3-cp39-cp39-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl (20 kB)
# Requirement already satisfied: pygments>=2.4.1 in /usr/lib/python3.9/site-packages (from nbconvert) (2.7.4)
# Collecting mistune<4,>=2.0.3
#   Downloading mistune-3.1.4-py3-none-any.whl (53 kB)
#      |████████████████████████████████| 53 kB 319 kB/s  eta 0:00:01
# Collecting jinja2>=3.0
#   Using cached jinja2-3.1.6-py3-none-any.whl (134 kB)
# Collecting nbclient>=0.5.0
#   Downloading nbclient-0.10.2-py3-none-any.whl (25 kB)
# Collecting webencodings
#   Downloading webencodings-0.5.1-py2.py3-none-any.whl (11 kB)
# Collecting tinycss2<1.5,>=1.1.0
#   Downloading tinycss2-1.4.0-py3-none-any.whl (26 kB)
# Collecting zipp>=3.20
#   Downloading zipp-3.23.0-py3-none-any.whl (10 kB)
# Collecting platformdirs>=2.5
#   Downloading platformdirs-4.4.0-py3-none-any.whl (18 kB)
# Collecting typing-extensions
#   Using cached typing_extensions-4.15.0-py3-none-any.whl (44 kB)
# Collecting jupyter-client>=6.1.12
#   Using cached jupyter_client-8.6.3-py3-none-any.whl (106 kB)
# Collecting python-dateutil>=2.8.2
#   Using cached python_dateutil-2.9.0.post0-py2.py3-none-any.whl (229 kB)
# Collecting tornado>=6.2
#   Using cached tornado-6.5.2-cp39-abi3-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (443 kB)
# Collecting pyzmq>=23.0
#   Downloading pyzmq-27.1.0-cp39-cp39-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (863 kB)
#      |████████████████████████████████| 863 kB 23.6 MB/s eta 0:00:01
# Collecting fastjsonschema>=2.15
#   Downloading fastjsonschema-2.21.2-py3-none-any.whl (24 kB)
# Collecting jsonschema>=2.6
#   Downloading jsonschema-4.25.1-py3-none-any.whl (90 kB)
#      |████████████████████████████████| 90 kB 8.1 MB/s  eta 0:00:011
# Collecting rpds-py>=0.7.1
#   Downloading rpds_py-0.27.1-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (384 kB)
#      |████████████████████████████████| 384 kB 43.7 MB/s eta 0:00:01
# Collecting attrs>=22.2.0
#   Using cached attrs-25.4.0-py3-none-any.whl (67 kB)
# Collecting jsonschema-specifications>=2023.03.6
#   Downloading jsonschema_specifications-2025.9.1-py3-none-any.whl (18 kB)
# Collecting referencing>=0.28.4
#   Downloading referencing-0.36.2-py3-none-any.whl (26 kB)
# Requirement already satisfied: six>=1.5 in /usr/lib/python3.9/site-packages (from python-dateutil>=2.8.2->jupyter-client>=6.1.12->nbclient>=0.5.0->nbconvert) (1.15.0)
# Collecting soupsieve>=1.6.1
#   Using cached soupsieve-2.8-py3-none-any.whl (36 kB)
# Requirement already satisfied: pyparsing>=2.0.2 in /usr/lib/python3.9/site-packages (from packaging->nbconvert) (2.4.7)
# Installing collected packages: typing-extensions, rpds-py, attrs, referencing, zipp, traitlets, platformdirs, jsonschema-specifications, webencodings, tornado, pyzmq, python-dateutil, jupyter-core, jsonschema, importlib-metadata, fastjsonschema, tinycss2, soupsieve, nbformat, markupsafe, jupyter-client, bleach, pandocfilters, nbclient, mistune, jupyterlab-pygments, jinja2, defusedxml, beautifulsoup4, nbconvert
#   WARNING: Value for scheme.platlib does not match. Please report this to <https://github.com/pypa/pip/issues/10151>
#   distutils: /home/iwu/qa8171/.local/lib/python3.9/site-packages
#   sysconfig: /home/iwu/qa8171/.local/lib64/python3.9/site-packages
#   WARNING: Additional context:
#   user = True
#   home = None
#   root = None
#   prefix = None
#   WARNING: The scripts jupyter, jupyter-migrate and jupyter-troubleshoot are installed in '/home/iwu/qa8171/.local/bin' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The script jsonschema is installed in '/home/iwu/qa8171/.local/bin' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The script jupyter-trust is installed in '/home/iwu/qa8171/.local/bin' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The scripts jupyter-kernel, jupyter-kernelspec and jupyter-run are installed in '/home/iwu/qa8171/.local/bin' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The script jupyter-execute is installed in '/home/iwu/qa8171/.local/bin' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The scripts jupyter-dejavu and jupyter-nbconvert are installed in '/home/iwu/qa8171/.local/bin' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
# Successfully installed attrs-25.4.0 beautifulsoup4-4.14.3 bleach-6.2.0 defusedxml-0.7.1 fastjsonschema-2.21.2 importlib-metadata-8.7.0 jinja2-3.1.6 jsonschema-4.25.1 jsonschema-specifications-2025.9.1 jupyter-client-8.6.3 jupyter-core-5.8.1 jupyterlab-pygments-0.3.0 markupsafe-3.0.3 mistune-3.1.4 nbclient-0.10.2 nbconvert-7.16.6 nbformat-5.10.4 pandocfilters-1.5.1 platformdirs-4.4.0 python-dateutil-2.9.0.post0 pyzmq-27.1.0 referencing-0.36.2 rpds-py-0.27.1 soupsieve-2.8 tinycss2-1.4.0 tornado-6.5.2 traitlets-5.14.3 typing-extensions-4.15.0 webencodings-0.5.1 zipp-3.23.0

# %%
import sys
# !{sys.executable} -m jupyter nbconvert --to python Generate_memmap_data.ipynb --output Generate_memmap_data.py
# Out:
# [NbConvertApp] Converting notebook Generate_memmap_data.ipynb to python
# [NbConvertApp] Writing 9632 bytes to Generate_memmap_data.py

# %%
import sys
# !{sys.executable} -m jupyter nbconvert --to python CPC_baseline_DE.ipynb --output CPC_baseline_5per_NoEmb.py
# Out:
# usage: jupyter.py [-h] [--version] [--config-dir] [--data-dir] [--runtime-dir]
#                   [--paths] [--json] [--debug]
#                   [subcommand]
#
# Jupyter: Interactive Computing
#
# positional arguments:
#   subcommand     the subcommand to launch
#
# options:
#   -h, --help     show this help message and exit
#   --version      show the versions of core jupyter packages and exit
#   --config-dir   show Jupyter config dir
#   --data-dir     show Jupyter data dir
#   --runtime-dir  show Jupyter runtime dir
#   --paths        show all Jupyter paths. Add --json for machine-readable
#                  format.
#   --json         output paths as machine-readable json
#   --debug        output debug information about paths
#
# Available subcommands: kernel kernelspec migrate run troubleshoot
#
# Jupyter command `jupyter-nbconvert` not found.

# %%
import sys
# !{sys.executable} -m jupyter nbconvert --to python CPC_fine_tune_DE.ipynb --output CPC_fine_tune_100per.py
# Out:
# usage: jupyter.py [-h] [--version] [--config-dir] [--data-dir] [--runtime-dir]
#                   [--paths] [--json] [--debug]
#                   [subcommand]
#
# Jupyter: Interactive Computing
#
# positional arguments:
#   subcommand     the subcommand to launch
#
# options:
#   -h, --help     show this help message and exit
#   --version      show the versions of core jupyter packages and exit
#   --config-dir   show Jupyter config dir
#   --data-dir     show Jupyter data dir
#   --runtime-dir  show Jupyter runtime dir
#   --paths        show all Jupyter paths. Add --json for machine-readable
#                  format.
#   --json         output paths as machine-readable json
#   --debug        output debug information about paths
#
# Available subcommands: kernel kernelspec migrate run troubleshoot
#
# Jupyter command `jupyter-nbconvert` not found.
